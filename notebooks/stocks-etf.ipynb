# %% [markdown]
# # simulate stock / global etf return rate over next X years

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# get data about LON:ISAC monthly from the last 5 years

# isac = yf.Ticker("VOO")
isac = yf.Ticker("ISAC.L")
isac_hist = isac.history(period="25y", interval="1mo")
isac_hist
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2011-11-01 00:00:00+00:00  25.100121  25.580000  23.950001  25.355000
# 2011-12-01 00:00:00+00:00  25.365000  25.870001  24.660000  25.219999
# 2012-01-01 00:00:00+00:00  25.190809  27.030001  27.030001  26.615000
# 2012-02-01 00:00:00+00:00  27.094999  28.250000  27.200001  27.950001
# 2012-03-01 00:00:00+00:00  28.080000  28.520000  27.660000  28.205000
# ...                              ...        ...        ...        ...
# 2023-12-01 00:00:00+00:00  72.150002  80.529999  71.809998  75.809998
# 2024-01-01 00:00:00+00:00  75.809998  76.900002  73.790001  76.459999
# 2024-02-01 00:00:00+00:00  76.070000  79.570000  76.000000  79.019997
# 2024-03-01 00:00:00+00:00  79.519997  82.120003  79.199997  81.800003
# 2024-04-01 00:00:00+01:00  81.800003  82.350021  78.389999  78.919998
#
#                             Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2011-11-01 00:00:00+00:00   622006        0.0           0.0            0.0
# 2011-12-01 00:00:00+00:00    55122        0.0           0.0            0.0
# 2012-01-01 00:00:00+00:00      861        0.0           0.0            0.0
# 2012-02-01 00:00:00+00:00    50661        0.0           0.0            0.0
# 2012-03-01 00:00:00+00:00    30730        0.0           0.0            0.0
# ...                            ...        ...           ...            ...
# 2023-12-01 00:00:00+00:00  4166030        0.0           0.0            0.0
# 2024-01-01 00:00:00+00:00  4628109        0.0           0.0            0.0
# 2024-02-01 00:00:00+00:00  3467697        0.0           0.0            0.0
# 2024-03-01 00:00:00+00:00  2794739        0.0           0.0            0.0
# 2024-04-01 00:00:00+01:00  3489000        0.0           0.0            0.0
#
# [150 rows x 8 columns]

# %%
returns = isac_hist['Close'].pct_change()
mu, sigma = returns.mean(), returns.std()
initial_price = isac_hist['Close'].iloc[-1]

print(f"Mean: {mu}")
print(f"Std: {sigma}")
# Out:
# Mean: 0.008432495493437286
# Std: 0.039591342753643205

# %%
years = 40
sim_rets = np.random.normal(mu, sigma, years*12)

# %%
sim_price = initial_price * (sim_rets + 1).cumprod()

px.line(x=np.arange(0, years, 1/12), y=sim_price, title="Simulated ISAC.L price over 40 years")

# %%
fig = px.line(x=np.arange(0, years, 1/12), y=sim_price, title="Simulated ISAC.L price over 40 years")
# accumulate 100 simulations

accumulated = np.zeros(years*12)

for i in range(100):
    sim_rets = np.random.normal(mu, sigma, years*12)
    sim_price = initial_price * (sim_rets + 1).cumprod()
    accumulated += sim_price
    fig.add_scatter(x=np.arange(0, years, 1/12), y=sim_price, mode='lines', line=dict(color='gray', width=0.5))

fig.show()

# %% [markdown]
# # get the mean from the accumulated results

# %%
# mean and std of the accumulated simulations
